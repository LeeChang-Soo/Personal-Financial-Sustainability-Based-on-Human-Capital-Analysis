# %%
import pandas as pd
import numpy as np
from gen_glide_path import *

# %%
income_process_coeff = np.array([-2.3055 + 7.8717, 0.3841, 0.0440, 0.1055, -0.0111, 0.0001])
characterized_vector = np.array([1, 1, 2, 25, 25**2/10, 25**3/100])

initial_hc = np.round(np.exp(income_process_coeff @ characterized_vector), -2)
initial_wealth = 1000

init_period = 35

# %%
mu_rf = 0.04
sigma_rf = 0.05

rho_rf = 0.2

mu_market = 0.12119
sigma_market = 0.334568

rho = -0.010961

mu_h = 0.04
sigma_h = 0.01#0.141262 + 0.005379
eta = 1.559863e-19

gamma = 5
size = 20000

# %% [markdown]
# __________________________________________
#
# ## 대학 졸업자에 대한 income process data를 가정한 glide path

# %%
glide_path = gen_glide_path(initial_wealth, initial_hc, init_period, size, mu_rf, sigma_rf, mu_market, sigma_market,
                            mu_h, sigma_h, eta, rho, gamma)
# Out:
# max: 1.0 , hc : 3000.0 , wealth 1000
# max: 1.0 , hc : 3244.8 , wealth 2199.8672781749997
# max: 0.9840865066466795 , hc : 3509.5756800000004 , wealth 3785.113358651795
# max: 0.9676780385465285 , hc : 3795.9570554880006 , wealth 5847.583716611141
# max: 0.8688158485234472 , hc : 4105.707151215822 , wealth 8503.800097197787
# max: 0.6541929200453186 , hc : 4440.732854755033 , wealth 11753.602352771719
# max: 0.6210472896771992 , hc : 4803.096655703044 , wealth 15370.912276718038
# max: 0.5345579104353877 , hc : 5195.029342808413 , wealth 19704.09887645149
# max: 0.5185737064039484 , hc : 5618.94373718158 , wealth 24652.253693755472
# max: 0.4358510518398873 , hc : 6077.449546135598 , wealth 30511.351252460303
# max: 0.3942068818453823 , hc : 6573.369429100264 , wealth 37042.13196521079
# max: 0.32757035412614194 , hc : 7109.756374514846 , wealth 44457.19730419138
# max: 0.340455441718162 , hc : 7689.912494675259 , wealth 52597.71643755714
# max: 0.31669444416160286 , hc : 8317.40935424076 , wealth 62145.30924264078
# max: 0.2395272734608248 , hc : 8996.109957546809 , wealth 72942.70764984873

# %%
income_process_coeff = np.array([7.8016 - 2.3326, 0.2550, 0.0537, 0.1232, -0.0193, 0.0011])
characterized_vector = np.array([1, 1, 2, 25, 25**2/10, 25**3/100])

initial_hc = np.round(np.exp(income_process_coeff @ characterized_vector), -2)
initial_wealth = 1000

init_period = 35

# %%
mu_rf = 0.04
sigma_rf = 0.05

rho_rf = 0.2

mu_market = 0.12119
sigma_market = 0.25

rho = 0.4

mu_h = 0.04
sigma_h = 0.01#0.145682 + 0.010166
eta = 1.302985e-18

gamma = 5
size = 20000

# %% [markdown]
# _________________________________________________
#
# ## 전문 대학 졸업자에 대한 income process data를 가정한 glide path

# %%
glide_path = gen_glide_path(initial_wealth, initial_hc, init_period, size, mu_rf, sigma_rf, mu_market, sigma_market, mu_h, sigma_h, eta, rho, gamma)
# Out:
# max: 0.4422697031606736 , hc : 2600.0 , wealth 1000
# max: 0.24809652376532917 , hc : 2812.1600000000003 , wealth 1910.0033043633002
# max: -0.013482714400968222 , hc : 3041.632256000001 , wealth 2936.807440882995
# max: 0.16326276876040505 , hc : 3289.829448089601 , wealth 3990.494544864879
# max: 0.2500974149852181 , hc : 3558.279531053713 , wealth 5339.232487546176
# max: 0.16805700797956713 , hc : 3848.6351407876964 , wealth 7002.715870371943
# max: 0.2124238152952271 , hc : 4162.683768275973 , wealth 8842.33968385779
# max: 0.17358127970758722 , hc : 4502.358763767294 , wealth 11046.938347461255
# max: 0.21190591482072507 , hc : 4869.751238890705 , wealth 13525.044259594917
# max: 0.1721377875050557 , hc : 5267.122939984188 , wealth 16477.40173484084
# max: 0.15659248686240776 , hc : 5696.920171886898 , wealth 19766.93678967927
# max: 0.1044571724292199 , hc : 6161.788857912869 , wealth 23484.1830376121
# max: 0.14237411628882998 , hc : 6664.59082871856 , wealth 27509.88011476382
# max: 0.14254674978033058 , hc : 7208.421440341996 , wealth 32262.18273539838
# max: 0.09593570707516268 , hc : 7796.628629873903 , wealth 37668.513026036664

# %%
income_process_coeff = np.array([7.5072 - 0.7417, 0.3198, 0.0590, 0.0124, 0.0064, -0.0009])
characterized_vector = np.array([1, 1, 2, 25, 25**2/10, 25**3/100])

initial_hc = np.round(np.exp(income_process_coeff @ characterized_vector), -2)
initial_wealth = 1000

init_period = 35

# %%
mu_rf = 0.04
sigma_rf = 0.05

rho_rf = 0.2

mu_market = 0.12119
sigma_market = 0.334568

rho = 0.633465

mu_h = 0.02
sigma_h = 0.174855 + 0.005461
eta = 1.550801e-18

gamma = 5
size = 20000

# %% [markdown]
# -----------------------------------------
#
# ## 고등학교 졸업자에 대한 income process data를 가정한 glide path

# %%
glide_path = gen_glide_path(initial_wealth, initial_hc, init_period, size, mu_rf, sigma_rf, mu_market, sigma_market, mu_h, sigma_h, eta, rho, gamma)
