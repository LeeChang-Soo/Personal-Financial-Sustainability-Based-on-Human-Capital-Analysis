# %%
import pandas as pd
import numpy as np
from gen_glide_path import *

# %%
income_process_coeff = np.array([-2.3055 + 7.8717, 0.3841, 0.0440, 0.1055, -0.0111, 0.0001])
characterized_vector = np.array([1, 1, 2, 25, 25**2/10, 25**3/100])

initial_hc = np.round(np.exp(income_process_coeff @ characterized_vector), -2)
initial_wealth = 1000

init_period = 35

# %%
mu_rf = 0.04
sigma_rf = 0.05

rho_rf = 0.2

mu_market = 0.1140
sigma_market = 0.2642608

rho = -0.010961

mu_h = 0.02
#sigma_h = 0.005379
sigma_h = 0.141262 + 0.005379
eta = 1.559863e-19

gamma = 5
size = 20000

# %% [markdown]
# __________________________________________
#
# ## 대학 졸업자에 대한 income process data를 가정한 glide path

# %%
glide_path = gen_glide_path(initial_wealth, initial_hc, init_period, size, mu_rf, sigma_rf, mu_market, sigma_market, 
                            mu_h, sigma_h, eta, rho, gamma)
# Out:
# max: 1.0 , hc : 3000.0 , wealth 1000
# max: 1.0 , hc : 3121.2 , wealth 2171.7430000000004
# max: 0.8073188270063704 , hc : 3247.29648 , wealth 3663.4735548280014
# max: 0.7986871524313391 , hc : 3378.487257792 , wealth 5412.566301188055
# max: 0.7162078420368974 , hc : 3514.978143006797 , wealth 7558.85264638956
# max: 0.5360096890455113 , hc : 3656.9832599842716 , wealth 10079.955606138192
# max: 0.524372534436851 , hc : 3804.725383687636 , wealth 12815.675648584558
# max: 0.4459969292955686 , hc : 3958.4362891886167 , wealth 16022.104097722144
# max: 0.43985283427966493 , hc : 4118.357115271837 , wealth 19586.21644551884
# max: 0.37469929730581186 , hc : 4284.738742728819 , wealth 23715.631109841124
# max: 0.33803857283715333 , hc : 4457.842187935063 , wealth 28258.024533482094
# max: 0.2834468909801014 , hc : 4637.939012327639 , wealth 33315.93623791198
# max: 0.2955707339280003 , hc : 4825.311748425675 , wealth 38807.881609788776
# ...

# %%
income_process_coeff = np.array([7.8016 - 2.3326, 0.2550, 0.0537, 0.1232, -0.0193, 0.0011])
characterized_vector = np.array([1, 1, 2, 25, 25**2/10, 25**3/100])

initial_hc = np.round(np.exp(income_process_coeff @ characterized_vector), -2)
initial_wealth = 1000

init_period = 35

# %%
mu_rf = 0.04
sigma_rf = 0.05

rho_rf = 0.2

mu_market = 0.1140
sigma_market = 0.2642608

rho = 0.3

mu_h = 0.02
#sigma_h = 0.010166
sigma_h = 0.145682 + 0.010166
eta = 1.302985e-18

gamma = 5
size = 20000

# %% [markdown]
# _________________________________________________
#
# ## 전문 대학 졸업자에 대한 income process data를 가정한 glide path

# %%
glide_path = gen_glide_path(initial_wealth, initial_hc, init_period, size, mu_rf, sigma_rf, mu_market, sigma_market, 
                            mu_h, sigma_h, eta, rho, gamma)
# Out:
# max: 1.0 , hc : 2400.0 , wealth 1000
# max: 0.9741756869530255 , hc : 2496.96 , wealth 1985.5936000000004
# max: 0.48857497742569556 , hc : 2597.837184 , wealth 3227.6906846185316
# max: 0.562595246736607 , hc : 2702.7898062336 , wealth 4490.160782144528
# max: 0.54905912372144 , hc : 2811.982514405437 , wealth 6043.681612133091
# max: 0.4080175611654319 , hc : 2925.5866079874168 , wealth 7878.513360001112
# max: 0.4220008739769822 , hc : 3043.7803069501083 , wealth 9861.04787830953
# max: 0.3583386141561082 , hc : 3166.7490313508924 , wealth 12189.050971558107
# max: 0.36890046927290926 , hc : 3294.6856922174684 , wealth 14765.052772469102
# max: 0.31490568497607 , hc : 3427.790994183054 , wealth 17757.526894452723
# max: 0.2854872807428455 , hc : 3566.2737503480494 , wealth 21045.77286085432
# max: 0.23452090220730673 , hc : 3710.3512098621104 , wealth 24701.194299278442
# max: 0.25392656393349505 , hc : 3860.2493987405396 , wealth 28652.943472100313
# ...

# %%
income_process_coeff = np.array([7.5072 - 0.7417, 0.3198, 0.0590, 0.0124, 0.0064, -0.0009])
characterized_vector = np.array([1, 1, 2, 25, 25**2/10, 25**3/100])

initial_hc = np.round(np.exp(income_process_coeff @ characterized_vector), -2)
initial_wealth = 1000

init_period = 35

# %%
mu_rf = 0.04
sigma_rf = 0.05

rho_rf = 0.2

mu_market = 0.1140
sigma_market = 0.2642608

rho = 0.633465

mu_h = 0.02
sigma_h = 0.005461
#sigma_h = 0.174855 + 0.005461
eta = 1.550801e-18

gamma = 5
size = 20000

# %% [markdown]
# -----------------------------------------
#
# ## 고등학교 졸업자에 대한 income process data를 가정한 glide path

# %%
glide_path = gen_glide_path(initial_wealth, initial_hc, init_period, size, mu_rf, sigma_rf, mu_market, sigma_market, 
                            mu_h, sigma_h, eta, rho, gamma)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-4c31a967bdf6> in <module>
#       1 glide_path = gen_glide_path(initial_wealth, initial_hc, init_period, size, mu_rf, sigma_rf, mu_market, sigma_market,
# ----> 2                             mu_h, sigma_h, eta, rho, gamma)
#
# ~\PycharmProjects\human_captial\gen_glide_path.py in gen_glide_path(initial_wealth, initial_hc, initial_period, size, mu_rf, sigma_rf, mu_market, sigma_market, mu_h, sigma_h, eta, rho, gamma)
#      28
#      29         max_utility = get_maxutility_weights(initial_wealth, initial_hc, period, size, mu_rf, sigma_rf, mu_market,
# ---> 30                                              sigma_market, mu_h, eta, sigma_h, rho, gamma)
#      31
#      32         glide.append(np.round(max_utility[0] * 100)[0])
#
# ...
